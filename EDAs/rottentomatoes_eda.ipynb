# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tomatoes_reviews = pd.read_csv("outside_data/rotten_tomatoes_critic_reviews.csv")
tomatoes_movies = pd.read_csv("outside_data/rotten_tomatoes_movies.csv")

print("Reviews columns:\n", tomatoes_reviews.columns, "\n")
print("Movies columns:\n", tomatoes_movies.columns)
# Out:
# Reviews columns:
#  Index(['rotten_tomatoes_link', 'critic_name', 'top_critic', 'publisher_name',
#        'review_type', 'review_score', 'review_date', 'review_content'],
#       dtype='object')
#
# Movies columns:
#  Index(['rotten_tomatoes_link', 'movie_title', 'movie_info',
#        'critics_consensus', 'content_rating', 'genres', 'directors', 'authors',
#        'actors', 'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'tomatometer_top_critics_count',
#        'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count'],
#       dtype='object')

# %% [markdown]
# ## Reviews cleaning

# %%
tomatoes_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130017 entries, 0 to 1130016
# Data columns (total 8 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   rotten_tomatoes_link  1130017 non-null  object
#  1   critic_name           1111488 non-null  object
#  2   top_critic            1130017 non-null  bool
#  3   publisher_name        1130017 non-null  object
#  4   review_type           1130017 non-null  object
#  5   review_score          824081 non-null   object
#  6   review_date           1130017 non-null  object
#  7   review_content        1064211 non-null  object
# dtypes: bool(1), object(7)
# memory usage: 61.4+ MB

# %%
tomatoes_reviews.isnull().sum()
# Out:
# rotten_tomatoes_link         0
# critic_name              18529
# top_critic                   0
# publisher_name               0
# review_type                  0
# review_score            305936
# review_date                  0
# review_content           65806
# dtype: int64

# %%
tomatoes_reviews.head(10)
# Out:
#   rotten_tomatoes_link       critic_name  top_critic           publisher_name  \
# 0            m/0814255   Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255     Louise Keller       False           Urban Cinefile
# 2            m/0814255               NaN       False      FILMINK (Australia)
# 3            m/0814255      Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255       Ethan Alter        True       Hollywood Reporter
# 5            m/0814255     David Germain        True         Associated Press
# 6            m/0814255      Nick Schager       False           Slant Magazine
# 7            m/0814255  Bill Goodykoontz        True         Arizona Republic
# 8            m/0814255    Jordan Hoffman       False                      UGO
# 9            m/0814255      Jim Schembri        True      The Age (Australia)
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
# 5      Rotten          NaN  2010-02-10
# 6      Rotten          1/4  2010-02-10
# 7       Fresh        3.5/5  2010-02-10
# 8       Fresh            B  2010-02-10
# 9       Fresh          3/5  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# 3  Whether audiences will get behind The Lightnin...
# 4  What's really lacking in The Lightning Thief i...
# 5  It's more a list of ingredients than a movie-m...
# 6  Harry Potter knockoffs don't come more transpa...
# 7  Percy Jackson isn't a great movie, but it's a ...
# 8                         Fun, brisk and imaginative
# 9  Crammed with dragons, set-destroying fights an...

# %% [markdown]
# We have some interesting data. Not all is relevant for our project so we can start by dropping some non useful columns.
# We will drop `critic_name`, `top_critic`, `publisher_name` and `review_date`
#
# We need the `rotten_tomatoes_link` to merge the movies df with the reviews we have have here
#
# `review_type` is highly useful actually, because this basically translates to the relevance label that we need to predict later on, so good stuff to keep in mind. The review score, even though it has a big amount of missing data, can give us some kind of indication on what represents a "Fresh" review and a "Rotten" review. Based on the head of the df we can see that there are values out of 5 and even 4, but also letters that represent the "grade" given to the movie.

# %%
tomatoes_reviews = tomatoes_reviews.drop(columns=["critic_name","top_critic", "publisher_name", "review_date"])
tomatoes_reviews
# Out:
#         rotten_tomatoes_link review_type review_score  \
# 0                  m/0814255       Fresh          NaN
# 1                  m/0814255       Fresh          NaN
# 2                  m/0814255       Fresh          NaN
# 3                  m/0814255       Fresh        3.5/5
# 4                  m/0814255      Rotten          NaN
# ...                      ...         ...          ...
# 1130012          m/zulu_dawn      Rotten          2/5
# 1130013          m/zulu_dawn       Fresh        3.5/5
# 1130014          m/zulu_dawn       Fresh           B+
# 1130015          m/zulu_dawn      Rotten        3.5/5
# 1130016          m/zulu_dawn      Rotten            C
#
#                                             review_content
# 0        A fantasy adventure that fuses Greek mythology...
# 1        Uma Thurman as Medusa, the gorgon with a coiff...
# 2        With a top-notch cast and dazzling special eff...
# 3        Whether audiences will get behind The Lightnin...
# 4        What's really lacking in The Lightning Thief i...
# ...                                                    ...
# 1130012                                                NaN
# 1130013  Seen today, it's not only a startling indictme...
# 1130014  A rousing visual spectacle that's a prequel of...
# 1130015  A simple two-act story: Prelude to war, and th...
# 1130016  Rides the line between being a pure artifact o...
#
# [1130017 rows x 4 columns]

# %%
tomatoes_reviews["review_content"] = tomatoes_reviews["review_content"].astype(str).str.replace(r'\[|\]', '', regex=True)
tomatoes_reviews["review_content"] = tomatoes_reviews["review_content"].astype(str).str.replace("nan", "", regex=True)
tomatoes_reviews["review_content"]
# Out:
# 0          A fantasy adventure that fuses Greek mythology...
# 1          Uma Thurman as Medusa, the gorgon with a coiff...
# 2          With a top-notch cast and dazzling special eff...
# 3          Whether audiences will get behind The Lightnin...
# 4          What's really lacking in The Lightning Thief i...
#                                  ...
# 1130012
# 1130013    Seen today, it's not only a startling indictme...
# 1130014    A rousing visual spectacle that's a prequel of...
# 1130015    A simple two-act story: Prelude to war, and th...
# 1130016    Rides the line between being a pure artifact o...
# Name: review_content, Length: 1130017, dtype: object

# %%
tomatoes_reviews["review_score"].value_counts()
# Out:
# review_score
# 3/5         90273
# 4/5         83659
# 3/4         72366
# 2/5         60174
# 2/4         47546
#             ...
# 9.66/10         1
# 9.99/10         1
# 5.751/10        1
# 3.515/10        1
# 3.85/10         1
# Name: count, Length: 814, dtype: int64

# %% [markdown]
# I realised that some reviews have sometimes [] that may be confused with a list inside the list so I think I rather remove them, just in case, that way it will be more flowy and the sentiment analysis wont mistake it

# %% [markdown]
# Looks like sometimes people like to be funny when ranking movies from time to time and give it random scores like 9.66.
# We dont necessarily need the score since we already have a "nullles" column `review_type` that gives us the relevance of the movie.
#
# We can check if all the movies have a score and putthing them together to obtain an average score that can be later translated to the `label` / `review_type`.
#
# There are also some good amount of reviews missing, but we can check if these are from movies that already have reviews and concatenate them together, based on the amount of movies present on the movies df, this will probably be the case.

# %% [markdown]
# Let's start with concatenating the reviews and data in general belonging to the same movies so that the merging with the movies df is easier.
# This will be easily achieved with groupby the `rotten_tomatoes_link` column, aggregating the rest of the columns and grouping them in lists for future information

# %%
grouped_tomatoes_df = tomatoes_reviews.groupby("rotten_tomatoes_link").agg(lambda x: x.tolist())
grouped_tomatoes_df.sample(15)
# Out:
#                                                                                     review_type  \
# rotten_tomatoes_link
# m/speed_1994                                  [Fresh, Fresh, Rotten, Fresh, Rotten, Fresh, F...
# m/taking_woodstock                            [Rotten, Rotten, Rotten, Fresh, Fresh, Fresh, ...
# m/dirty_shame                                 [Fresh, Rotten, Fresh, Fresh, Fresh, Fresh, Fr...
# m/haxan                                       [Fresh, Rotten, Fresh, Fresh, Fresh, Fresh, Fr...
# m/mission_impossible_fallout                  [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# m/1046151-fearless                            [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Rot...
# m/annabelle_comes_home                        [Fresh, Rotten, Rotten, Fresh, Fresh, Rotten, ...
# m/the_prince_2015                             [Rotten, Rotten, Rotten, Rotten, Rotten, Rotte...
# m/crazy_people                                [Rotten, Rotten, Rotten, Rotten, Rotten, Fresh...
# m/hh-holmes-americas-first-serial-killer      [Fresh, Fresh, Fresh, Fresh, Rotten, Fresh, Ro...
# m/captain_america_civil_war                   [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# m/dior_and_i                                  [Fresh, Rotten, Fresh, Fresh, Fresh, Fresh, Fr...
# m/stella_days                                 [Fresh, Fresh, Fresh, Fresh, Rotten, Rotten, F...
# m/1011338-jungle_book                         [Fresh, Rotten, Fresh, Fresh, Rotten, Rotten, ...
# m/fireball-500-thunder-alley-double-featureX  [Rotten, Rotten, Rotten, Rotten, Rotten, Rotte...
#
#                                                                                    review_score  \
# rotten_tomatoes_link
# m/speed_1994                                  [A, A, 5/10, 3/4, nan, nan, 3.5/4, 9/10, 3.5/4...
# m/taking_woodstock                            [nan, nan, nan, 3/5, 3/5, nan, nan, nan, nan, ...
# m/dirty_shame                                 [3/4, 1.5/5, 3.5/4, 2.5/4, 2.5/4, nan, nan, 1/...
# m/haxan                                       [3.5/4, 2.5/4, 3.5/5, 3.5/5, 3.5/4, B, 4/5, A-...
# m/mission_impossible_fallout                  [4/5, 8/10, A, A, nan, 5/5, nan, nan, nan, nan...
# m/1046151-fearless                            [B, 3.5/4, 3/4, 6/10, nan, 4/5, 5/10, nan, nan...
# m/annabelle_comes_home                        [nan, nan, 2/5, 4/5, 2.5/4, 2/5, 1.5/5, 2.5/4,...
# m/the_prince_2015                             [nan, 1/5, nan, nan, nan, 1.5/5, 1/5, D, nan, ...
# m/crazy_people                                [D-, 2/5, 2/4, 1/5, 2/5, 3/5, 3/5, nan, 2/4, 5...
# m/hh-holmes-americas-first-serial-killer        [4.5/5, 3.5/5, 3/5, 3/5, 3/5, A, 42/100, 3.5/5]
# m/captain_america_civil_war                   [A-, nan, 3.5/4, nan, nan, 5/5, 7.8/10, nan, 6...
# m/dior_and_i                                  [B+, 2.5/4, B, 4/5, 3/5, 3/5, B, 3/5, nan, 3/5...
# m/stella_days                                 [nan, nan, nan, nan, 2.5/5, nan, B-, 2.5/5, na...
# m/1011338-jungle_book                         [nan, C+, 4/5, B, nan, nan, nan, 3/5, nan, nan...
# m/fireball-500-thunder-alley-double-featureX  [2/5, 1.5/5, 2/5, 2/5, 1/5, 2/5, 2/5, 3/5, nan...
#
#                                                                                  review_content
# rotten_tomatoes_link
# m/speed_1994                                  [The film takes off from formula elements, but...
# m/taking_woodstock                            [Demetri Martin makes little impression as Tib...
# m/dirty_shame                                 [This NC-17 freak show could just as easily ha...
# m/haxan                                       [A truly unique work that still holds the powe...
# m/mission_impossible_fallout                  [Mission: Impossible - Fallout is going to blo...
# m/1046151-fearless                            [, , "Fearless" is like a short story that shi...
# m/annabelle_comes_home                        [Unlike previous films, where the human cast w...
# m/the_prince_2015                             [Macho mayhem as the male version of maternal ...
# m/crazy_people                                [, , I wonder if they have a squad out in Holl...
# m/hh-holmes-americas-first-serial-killer      [There's a current that runs through this movi...
# m/captain_america_civil_war                   [The Russos deftly craft compelling blockbuste...
# m/dior_and_i                                  [...Dior And I succeeds in bringing this exclu...
# m/stella_days                                 [Thanks to its understated elegance and surpas...
# m/1011338-jungle_book                         [Click to read the article. (Lists all Jungle ...
# m/fireball-500-thunder-alley-double-featureX  [The few women in the cast look aghast at what...

# %%
grouped_tomatoes_df['review_type'].str.len().value_counts()
print(grouped_tomatoes_df['review_type'].str.len().min())
print(grouped_tomatoes_df['review_type'].str.len().max())
# Out:
# 1
# 992

# %%
grouped_tomatoes_df[grouped_tomatoes_df["review_type"].apply(lambda lst: isinstance(lst, list) and len(lst) == 1)]

#grouped_tomatoes_df[grouped_tomatoes_df["review_type"].apply(lambda lst: isinstance(lst, list) and len(lst) == 4)]
# Out:
#                      review_type review_score review_content
# rotten_tomatoes_link
# m/farewell_2010          [Fresh]        [3/5]             []

# %% [markdown]
# Since the only column that only has one review has not review_content, might as well opt for the choice of dropping all the rows in the original df (without grouping) that contain any nan values. That way we still have a big amount of data with no no missing values.

# %%
tomatoes_reviews = tomatoes_reviews.dropna()
tomatoes_reviews
# Out:
#         rotten_tomatoes_link review_type review_score  \
# 3                  m/0814255       Fresh        3.5/5
# 6                  m/0814255      Rotten          1/4
# 7                  m/0814255       Fresh        3.5/5
# 8                  m/0814255       Fresh            B
# 9                  m/0814255       Fresh          3/5
# ...                      ...         ...          ...
# 1130012          m/zulu_dawn      Rotten          2/5
# 1130013          m/zulu_dawn       Fresh        3.5/5
# 1130014          m/zulu_dawn       Fresh           B+
# 1130015          m/zulu_dawn      Rotten        3.5/5
# 1130016          m/zulu_dawn      Rotten            C
#
#                                             review_content
# 3        Whether audiences will get behind The Lightnin...
# 6        Harry Potter knockoffs don't come more transpa...
# 7        Percy Jackson isn't a great movie, but it's a ...
# 8                               Fun, brisk and imaginative
# 9        Crammed with dragons, set-destroying fights an...
# ...                                                    ...
# 1130012
# 1130013  Seen today, it's not only a startling indictme...
# 1130014  A rousing visual spectacle that's a prequel of...
# 1130015  A simple two-act story: Prelude to war, and th...
# 1130016  Rides the line between being a pure artifact o...
#
# [824081 rows x 4 columns]

# %%
df_reviews = tomatoes_reviews.groupby("rotten_tomatoes_link").agg(lambda x: x.tolist())
df_reviews.sample(15)
# Out:
#                                                                         review_type  \
# rotten_tomatoes_link
# m/art_isthe_permanent_revolution                              [Fresh, Fresh, Fresh]
# m/playing_mona_lisa               [Rotten, Fresh, Fresh, Fresh, Fresh, Rotten, F...
# m/dazed_and_confused              [Fresh, Fresh, Fresh, Fresh, Rotten, Fresh, Fr...
# m/kung_pow                        [Rotten, Rotten, Rotten, Rotten, Fresh, Rotten...
# m/absolutely_anything             [Fresh, Rotten, Rotten, Rotten, Rotten, Rotten...
# m/broken_embraces                 [Rotten, Fresh, Fresh, Fresh, Fresh, Fresh, Fr...
# m/the_space_between_us            [Rotten, Fresh, Rotten, Fresh, Rotten, Rotten,...
# m/nightmare_man                                       [Fresh, Fresh, Fresh, Rotten]
# m/prince_of_tides                 [Rotten, Rotten, Fresh, Fresh, Fresh, Fresh, R...
# m/borg_vs_mcenroe                 [Rotten, Rotten, Rotten, Rotten, Fresh, Fresh,...
# m/true_history_of_the_kelly_gang  [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Rot...
# m/breathless                      [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# m/1036458-dogfight                [Rotten, Fresh, Fresh, Fresh, Fresh, Fresh, Ro...
# m/chasing_amy                     [Fresh, Fresh, Fresh, Fresh, Fresh, Rotten, Fr...
# m/thale_2012                                   [Fresh, Fresh, Fresh, Rotten, Fresh]
#
#                                                                        review_score  \
# rotten_tomatoes_link
# m/art_isthe_permanent_revolution                                    [3/4, 4/5, 3/5]
# m/playing_mona_lisa               [1.5/4, 3/4, 1/4, 3/5, 3/5, 1.5/5, 3/4, 1/5, 3...
# m/dazed_and_confused              [A, 7/10, 4.5/5, 3/4, 2/4, 2.5/4, 4.5/5, 5/5, ...
# m/kung_pow                        [1.5/4, 1/5, 0.5/4, 0/4, 2.5/4, 2/4, 2/5, 1.5/...
# m/absolutely_anything             [3/5, 2/5, 1/5, 2/5, 2/5, 2/5, 0/5, 1/5, 2/5, ...
# m/broken_embraces                 [2/5, 3/5, B+, 4/5, 4/5, 4/5, 4/5, 4/5, 3/5, 4...
# m/the_space_between_us            [2/5, B, 2.5/5, B-, 4/10, C+, 1.5/4, 3/5, D, 1...
# m/nightmare_man                                            [4.5/5, 3/5, 2.5/4, 2/5]
# m/prince_of_tides                 [C, C, 3.5/4, 3/5, 3.5/4, 3/5, 67/100, 67/100,...
# m/borg_vs_mcenroe                 [2/5, 5/10, 2/5, 3/5, 6/10, 4/5, 3/4, 6/10, C,...
# m/true_history_of_the_kelly_gang  [B-, B-, B+, B, 3.5/5, 7/10, D-, 4/5, 5/5, 18....
# m/breathless                      [4.5/5, 5/5, 4/5, 3.5/5, 4/4, 4/4, 4/4, 5/5, 4...
# m/1036458-dogfight                [C, 4/4, 4/5, 3/4, 3/5, 4/5, 2/5, 4/5, 3/5, 4/...
# m/chasing_amy                     [4/5, 3.5/4, 3.5/4, 4/5, 2.5/4, 2/4, 2.5/4, 3/...
# m/thale_2012                                                  [3/5, B, 3/5, C, 4/5]
#
#                                                                      review_content
# rotten_tomatoes_link
# m/art_isthe_permanent_revolution  [The premise of this brief portrait sketch is ...
# m/playing_mona_lisa               [Devoid of almost any comedic energy., , , , ,...
# m/dazed_and_confused              [Once every decade or so, a movie captures the...
# m/kung_pow                        [The dose is strong and funny, for the first 1...
# m/absolutely_anything             [It's all on Pegg and his goofy charisma to ke...
# m/broken_embraces                 [Feels like a mixed bag of smart ideas and nod...
# m/the_space_between_us            [Call it The Unspectacular Now...We're suppose...
# m/nightmare_man                   [A solid, whirlwind of a horror movie, with mo...
# m/prince_of_tides                 [The Prince of Tides is a big, messy, go-for-t...
# m/borg_vs_mcenroe                 [Ronnie Sandahl's script is frustratingly simp...
# m/true_history_of_the_kelly_gang  [Justin Kurzel's visual style and peculiar nar...
# m/breathless                      [, A revolution swept French cinema into the 1...
# m/1036458-dogfight                [, A virtually unknown gem, and is one of the ...
# m/chasing_amy                     [Hip, clever, and outrageous, While the surfac...
# m/thale_2012                      [Thale packs a lot of character and atmosphere...

# %%
df_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17676 entries, m/+_one_2019 to m/zulu_dawn
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   review_type     17676 non-null  object
#  1   review_score    17676 non-null  object
#  2   review_content  17676 non-null  object
# dtypes: object(3)
# memory usage: 552.4+ KB

# %% [markdown]
# Now we have all the reviews concatenated for each movie and their ratings, rotten or fresh (relevant/non-relevant)
#
# We can count the amount of time the word `Rotten` or `Fresh` appears and make average it to find the overall rating. At the same time this is what we  already want to do with sentiment analysis, so it is a good oportunity to check its performance.

# %%
df_reviews['review_type'].apply(lambda lst: lst.count("Fresh"))
# Out:
# rotten_tomatoes_link
# m/+_one_2019                        40
# m/+h                                 2
# m/-_man                             18
# m/-cule_valley_of_the_lost_ants      6
# m/0814255                           58
#                                   ...
# m/zoot_suit                          3
# m/zootopia                         201
# m/zorba_the_greek                    6
# m/zulu                              16
# m/zulu_dawn                          4
# Name: review_type, Length: 17676, dtype: int64

# %%
def determine_dominant(lst):
    fresh_count = lst.count("Fresh")
    rotten_count = lst.count("Rotten")
    return "Fresh" if fresh_count > rotten_count else "Rotten"

try_out = df_reviews['review_type'].apply(determine_dominant)
try_out
# Out:
# rotten_tomatoes_link
# m/+_one_2019                        Fresh
# m/+h                               Rotten
# m/-_man                             Fresh
# m/-cule_valley_of_the_lost_ants     Fresh
# m/0814255                          Rotten
#                                     ...
# m/zoot_suit                         Fresh
# m/zootopia                          Fresh
# m/zorba_the_greek                   Fresh
# m/zulu                              Fresh
# m/zulu_dawn                        Rotten
# Name: review_type, Length: 17676, dtype: object

# %%
df_reviews["review_label"] = try_out
df_reviews
# Out:
#                                                                        review_type  \
# rotten_tomatoes_link
# m/+_one_2019                     [Fresh, Fresh, Fresh, Fresh, Fresh, Rotten, Fr...
# m/+h                                [Fresh, Rotten, Rotten, Fresh, Rotten, Rotten]
# m/-_man                          [Fresh, Rotten, Fresh, Fresh, Rotten, Rotten, ...
# m/-cule_valley_of_the_lost_ants  [Rotten, Fresh, Fresh, Fresh, Fresh, Fresh, Fr...
# m/0814255                        [Fresh, Rotten, Fresh, Fresh, Fresh, Fresh, Ro...
# ...                                                                            ...
# m/zoot_suit                                  [Rotten, Fresh, Fresh, Fresh, Rotten]
# m/zootopia                       [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# m/zorba_the_greek                [Fresh, Fresh, Rotten, Fresh, Fresh, Fresh, Fr...
# m/zulu                           [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# m/zulu_dawn                      [Rotten, Fresh, Fresh, Rotten, Fresh, Fresh, R...
#
#                                                                       review_score  \
# rotten_tomatoes_link
# m/+_one_2019                     [3/4, B, 8/10, 4.5/5, B, 2/5, 4/5, B, 3/4, 4/5...
# m/+h                                              [B+, 0.5/4, D, 8/10, 1/5, 1.5/4]
# m/-_man                          [B, 2.5/4, 3/4, 3/4, 2.5/4, 1.5/5, 7/10, B, 3/...
# m/-cule_valley_of_the_lost_ants             [1.5/5, 3/5, 4/5, 4/5, 3/5, 4/5, 8/10]
# m/0814255                        [3.5/5, 1/4, 3.5/5, B, 3/5, 4/5, 2/4, 2/5, 3/5...
# ...                                                                            ...
# m/zoot_suit                                               [1/5, 3/5, B-, 3/5, 2/5]
# m/zootopia                       [4/5, 6/10, 4/5, 4/5, 9/10, 8.5/10, 3.5/5, 5/5...
# m/zorba_the_greek                              [4/5, 4/5, C+, B, 4/5, 3/4, 79/100]
# m/zulu                           [4/5, 5/5, A, 4/5, 4/5, 4/5, 4/5, 2.5/4, 3/5, ...
# m/zulu_dawn                              [2/5, 3/5, 4/5, 2/5, 3.5/5, B+, 3.5/5, C]
#
#                                                                     review_content  \
# rotten_tomatoes_link
# m/+_one_2019                     [This charming rom com goes to a lot of expect...
# m/+h                             [Ultimately Plush exceeds its very limited exp...
# m/-_man                          [, Too many pieces of the puzzle are left out ...
# m/-cule_valley_of_the_lost_ants  [Over the course of 90-odd minutes its charm w...
# m/0814255                        [Whether audiences will get behind The Lightni...
# ...                                                                            ...
# m/zoot_suit                      [, , , A curious film with a hint of authentic...
# m/zootopia                       [The be-true-to-yourself and don't-judge-other...
# m/zorba_the_greek                [, , Gained international acclaim for Anthony ...
# m/zulu                           [, This amazing film is devastatingly accurate...
# m/zulu_dawn                      [, , , , Seen today, it's not only a startling...
#
#                                 review_label
# rotten_tomatoes_link
# m/+_one_2019                           Fresh
# m/+h                                  Rotten
# m/-_man                                Fresh
# m/-cule_valley_of_the_lost_ants        Fresh
# m/0814255                             Rotten
# ...                                      ...
# m/zoot_suit                            Fresh
# m/zootopia                             Fresh
# m/zorba_the_greek                      Fresh
# m/zulu                                 Fresh
# m/zulu_dawn                           Rotten
#
# [17676 rows x 4 columns]

# %% [markdown]
# ## Movies cleaning

# %%
tomatoes_movies.columns
# Out:
# Index(['rotten_tomatoes_link', 'movie_title', 'movie_info',
#        'critics_consensus', 'content_rating', 'genres', 'directors', 'authors',
#        'actors', 'original_release_date', 'streaming_release_date', 'runtime',
#        'production_company', 'tomatometer_status', 'tomatometer_rating',
#        'tomatometer_count', 'audience_status', 'audience_rating',
#        'audience_count', 'tomatometer_top_critics_count',
#        'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count'],
#       dtype='object')

# %%
tomatoes_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17712 entries, 0 to 17711
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   rotten_tomatoes_link              17712 non-null  object
#  1   movie_title                       17712 non-null  object
#  2   movie_info                        17391 non-null  object
#  3   critics_consensus                 9134 non-null   object
#  4   content_rating                    17712 non-null  object
#  5   genres                            17693 non-null  object
#  6   directors                         17518 non-null  object
#  7   authors                           16170 non-null  object
#  8   actors                            17360 non-null  object
#  9   original_release_date             16546 non-null  object
#  10  streaming_release_date            17328 non-null  object
#  11  runtime                           17398 non-null  float64
#  12  production_company                17213 non-null  object
#  13  tomatometer_status                17668 non-null  object
#  14  tomatometer_rating                17668 non-null  float64
#  15  tomatometer_count                 17668 non-null  float64
#  16  audience_status                   17264 non-null  object
#  17  audience_rating                   17416 non-null  float64
#  18  audience_count                    17415 non-null  float64
#  19  tomatometer_top_critics_count     17712 non-null  int64
#  20  tomatometer_fresh_critics_count   17712 non-null  int64
#  21  tomatometer_rotten_critics_count  17712 non-null  int64
# dtypes: float64(5), int64(3), object(14)
# memory usage: 3.0+ MB

# %%
tomatoes_movies["rotten_tomatoes_link"].unique()
# Out:
# array(['m/0814255', 'm/0878835', 'm/10', ..., 'm/zorba_the_greek',
#        'm/zulu', 'm/zulu_dawn'], shape=(17712,), dtype=object)

# %%
tomatoes_movies.isnull().sum()
# Out:
# rotten_tomatoes_link                   0
# movie_title                            0
# movie_info                           321
# critics_consensus                   8578
# content_rating                         0
# genres                                19
# directors                            194
# authors                             1542
# actors                               352
# original_release_date               1166
# streaming_release_date               384
# runtime                              314
# production_company                   499
# tomatometer_status                    44
# tomatometer_rating                    44
# tomatometer_count                     44
# audience_status                      448
# audience_rating                      296
# audience_count                       297
# tomatometer_top_critics_count          0
# tomatometer_fresh_critics_count        0
# tomatometer_rotten_critics_count       0
# dtype: int64

# %%
tomatoes_movies
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 17707                                          Zoot Suit
# 17708                                           Zootopia
# 17709                                    Zorba the Greek
# 17710                                               Zulu
# 17711                                          Zulu Dawn
#
#                                               movie_info  \
# 0      Always trouble-prone, the life of teenager Per...
# 1      Kate (Catherine Keener) and her husband Alex (...
# 2      A successful, middle-aged Hollywood songwriter...
# 3      Following the closing arguments in a murder tr...
# 4      In 1866, Professor Pierre M. Aronnax (Paul Luk...
# ...                                                  ...
# 17707  Mexican-American gangster Henry Reyna (Daniel ...
# 17708  From the largest elephant to the smallest shre...
# 17709  Traveling to inspect an abandoned mine his fat...
# 17710  In 1879, the Zulu nation hands colonial Britis...
# 17711  Sir Henry Bartle Frere's (John Mills) vastly o...
#
#                                        critics_consensus content_rating  \
# 0      Though it may seem like just another Harry Pot...             PG
# 1      Nicole Holofcener's newest might seem slight i...              R
# 2      Blake Edwards' bawdy comedy may not score a pe...              R
# 3      Sidney Lumet's feature debut is a superbly wri...             NR
# 4      One of Disney's finest live-action adventures,...              G
# ...                                                  ...            ...
# 17707                                                NaN              R
# 17708  The brilliantly well-rounded Zootopia offers a...             PG
# 17709                                                NaN             NR
# 17710  Zulu patiently establishes a cast of colorful ...             PG
# 17711                                                NaN             PG
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 17707                   Drama, Musical & Performing Arts
# 17708              Action & Adventure, Animation, Comedy
# 17709  Action & Adventure, Art House & International,...
# 17710                                    Classics, Drama
# 17711  Action & Adventure, Art House & International,...
#
#                                   directors  \
# 0                            Chris Columbus
# 1                         Nicole Holofcener
# 2                             Blake Edwards
# 3                              Sidney Lumet
# 4                         Richard Fleischer
# ...                                     ...
# 17707                           Luis Valdez
# 17708  Byron Howard, Rich Moore, Jared Bush
# 17709                                   NaN
# 17710           Cy Endfield, Cyril Endfield
# 17711                        Douglas Hickox
#
#                                           authors  \
# 0      Craig Titley, Chris Columbus, Rick Riordan
# 1                               Nicole Holofcener
# 2                                   Blake Edwards
# 3                                   Reginald Rose
# 4                                     Earl Felton
# ...                                           ...
# 17707                                 Luis Valdez
# 17708                   Jared Bush, Phil Johnston
# 17709                                         NaN
# 17710                   Cy Endfield, John Prebble
# 17711                 Cy Endfield, Anthony Storey
#
#                                                   actors  \
# 0      Logan Lerman, Brandon T. Jackson, Alexandra Da...
# 1      Catherine Keener, Amanda Peet, Oliver Platt, R...
# 2      Dudley Moore, Bo Derek, Julie Andrews, Robert ...
# 3      Martin Balsam, John Fiedler, Lee J. Cobb, E.G....
# 4      James Mason, Kirk Douglas, Paul Lukas, Peter L...
# ...                                                  ...
# 17707  Daniel Valdez, Edward James Olmos, Charles Aid...
# 17708  J.K. Simmons, Kristen Bell, Octavia Spencer, A...
# 17709  Anthony Quinn, Alan Bates, Irene Papas, Lila K...
# 17710  Stanley Baker, Jack Hawkins, Ulla Jacobsson, J...
# 17711  Burt Lancaster, Peter O'Toole, Simon Ward, Joh...
#
#       original_release_date  ...             production_company  \
# 0                2010-02-12  ...               20th Century Fox
# 1                2010-04-30  ...         Sony Pictures Classics
# 2                1979-10-05  ...                    Waner Bros.
# 3                1957-04-13  ...           Criterion Collection
# 4                1954-01-01  ...                         Disney
# ...                     ...  ...                            ...
# 17707            1981-10-02  ...       MCA Universal Home Video
# 17708            2016-03-04  ...  Walt Disney Animation Studios
# 17709            1964-12-17  ...                            Fox
# 17710            1964-06-17  ...             Paramount Pictures
# 17711            1979-12-14  ...            Tango Entertainment
#
#        tomatometer_status tomatometer_rating tomatometer_count  \
# 0                  Rotten               49.0             149.0
# 1         Certified-Fresh               87.0             142.0
# 2                   Fresh               67.0              24.0
# 3         Certified-Fresh              100.0              54.0
# 4                   Fresh               89.0              27.0
# ...                   ...                ...               ...
# 17707              Rotten               56.0               9.0
# 17708     Certified-Fresh               98.0             291.0
# 17709               Fresh               80.0              10.0
# 17710               Fresh               96.0              23.0
# 17711              Rotten               50.0               8.0
#
#        audience_status  audience_rating audience_count  \
# 0              Spilled             53.0       254421.0
# 1              Upright             64.0        11574.0
# 2              Spilled             53.0        14684.0
# 3              Upright             97.0       105386.0
# 4              Upright             74.0        68918.0
# ...                ...              ...            ...
# 17707          Upright             74.0         1195.0
# 17708          Upright             92.0       101511.0
# 17709          Upright             86.0         7146.0
# 17710          Upright             91.0        30193.0
# 17711          Upright             62.0         4469.0
#
#        tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                                 43                               73
# 1                                 44                              123
# 2                                  2                               16
# 3                                  6                               54
# 4                                  5                               24
# ...                              ...                              ...
# 17707                              2                                5
# 17708                             50                              285
# 17709                              0                                8
# 17710                              6                               22
# 17711                              0                                4
#
#        tomatometer_rotten_critics_count
# 0                                    76
# 1                                    19
# 2                                     8
# 3                                     0
# 4                                     3
# ...                                 ...
# 17707                                 4
# 17708                                 7
# 17709                                 2
# 17710                                 1
# 17711                                 4
#
# [17712 rows x 22 columns]

# %% [markdown]
# Starting with dropping unnecessary columns, we can easily say that we can drop:
# - `directors`
# - `authors`
# - `actors`
# - `streaming_release_date` (rather have the original release date)
# - `runtime`
# - `tomatometer_count`
# - `audience_count`
# - `tomatometer_top_critics_count`
# - `tomatometer_fresh_critics_count`
# - `tomatometer_rotten_critics_count`
#
# I'm doubting whether we want the `movie_info` column to still be there since we don't necessarily want to know about the plot of the movie but about what people think about the movie, aka the reviews. I will drop it for now.
#
# The column `original_release_date` has year-month-day structure, which is not the most useful so we can just get rid of the month and day and just keep the year for easier manipulation when it comes to merging with the reviews df.

# %%
tomatoes_movies = tomatoes_movies.drop(columns=[
    "directors", 
    "authors", 
    "actors", 
    "streaming_release_date", 
    "runtime", 
    "tomatometer_count", 
    "audience_count",
    "tomatometer_top_critics_count",
    "tomatometer_fresh_critics_count",
    "tomatometer_rotten_critics_count",
    "movie_info"
    ])

tomatoes_movies
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17707                            m/zoot_suit
# 17708                             m/zootopia
# 17709                      m/zorba_the_greek
# 17710                                 m/zulu
# 17711                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 17707                                          Zoot Suit
# 17708                                           Zootopia
# 17709                                    Zorba the Greek
# 17710                                               Zulu
# 17711                                          Zulu Dawn
#
#                                        critics_consensus content_rating  \
# 0      Though it may seem like just another Harry Pot...             PG
# 1      Nicole Holofcener's newest might seem slight i...              R
# 2      Blake Edwards' bawdy comedy may not score a pe...              R
# 3      Sidney Lumet's feature debut is a superbly wri...             NR
# 4      One of Disney's finest live-action adventures,...              G
# ...                                                  ...            ...
# 17707                                                NaN              R
# 17708  The brilliantly well-rounded Zootopia offers a...             PG
# 17709                                                NaN             NR
# 17710  Zulu patiently establishes a cast of colorful ...             PG
# 17711                                                NaN             PG
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 17707                   Drama, Musical & Performing Arts
# 17708              Action & Adventure, Animation, Comedy
# 17709  Action & Adventure, Art House & International,...
# 17710                                    Classics, Drama
# 17711  Action & Adventure, Art House & International,...
#
#       original_release_date             production_company tomatometer_status  \
# 0                2010-02-12               20th Century Fox             Rotten
# 1                2010-04-30         Sony Pictures Classics    Certified-Fresh
# 2                1979-10-05                    Waner Bros.              Fresh
# 3                1957-04-13           Criterion Collection    Certified-Fresh
# 4                1954-01-01                         Disney              Fresh
# ...                     ...                            ...                ...
# 17707            1981-10-02       MCA Universal Home Video             Rotten
# 17708            2016-03-04  Walt Disney Animation Studios    Certified-Fresh
# 17709            1964-12-17                            Fox              Fresh
# 17710            1964-06-17             Paramount Pictures              Fresh
# 17711            1979-12-14            Tango Entertainment             Rotten
#
#        tomatometer_rating audience_status  audience_rating
# 0                    49.0         Spilled             53.0
# 1                    87.0         Upright             64.0
# 2                    67.0         Spilled             53.0
# 3                   100.0         Upright             97.0
# 4                    89.0         Upright             74.0
# ...                   ...             ...              ...
# 17707                56.0         Upright             74.0
# 17708                98.0         Upright             92.0
# 17709                80.0         Upright             86.0
# 17710                96.0         Upright             91.0
# 17711                50.0         Upright             62.0
#
# [17712 rows x 11 columns]

# %% [markdown]
# Changing the format of the `original_release_date` column.

# %%
tomatoes_movies["original_release_date"] = tomatoes_movies["original_release_date"].apply(
    lambda x: int(str(x)[:4]) if pd.notna(x) and str(x)[:4].isdigit() else None
).astype("Int64")

tomatoes_movies["original_release_date"]
# Out:
# 0        2010
# 1        2010
# 2        1979
# 3        1957
# 4        1954
#          ...
# 17707    1981
# 17708    2016
# 17709    1964
# 17710    1964
# 17711    1979
# Name: original_release_date, Length: 17712, dtype: Int64

# %% [markdown]
# Let's check the amount of missing reviews

# %%
tomatoes_movies["critics_consensus"].isnull().sum()
# Out:
# np.int64(8578)

# %% [markdown]
# We need to make sure that after merging and adding the `critics_consense` to the `reviews_content` we don't add the `NaN` values to the lists

# %% [markdown]
# ## Time to merge

# %%
tomatoes_data = tomatoes_movies.merge(df_reviews, on="rotten_tomatoes_link")
tomatoes_data
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 17665                            m/zoot_suit
# 17666                             m/zootopia
# 17667                      m/zorba_the_greek
# 17668                                 m/zulu
# 17669                            m/zulu_dawn
#
#                                              movie_title  \
# 0      Percy Jackson & the Olympians: The Lightning T...
# 1                                            Please Give
# 2                                                     10
# 3                        12 Angry Men (Twelve Angry Men)
# 4                           20,000 Leagues Under The Sea
# ...                                                  ...
# 17665                                          Zoot Suit
# 17666                                           Zootopia
# 17667                                    Zorba the Greek
# 17668                                               Zulu
# 17669                                          Zulu Dawn
#
#                                        critics_consensus content_rating  \
# 0      Though it may seem like just another Harry Pot...             PG
# 1      Nicole Holofcener's newest might seem slight i...              R
# 2      Blake Edwards' bawdy comedy may not score a pe...              R
# 3      Sidney Lumet's feature debut is a superbly wri...             NR
# 4      One of Disney's finest live-action adventures,...              G
# ...                                                  ...            ...
# 17665                                                NaN              R
# 17666  The brilliantly well-rounded Zootopia offers a...             PG
# 17667                                                NaN             NR
# 17668  Zulu patiently establishes a cast of colorful ...             PG
# 17669                                                NaN             PG
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 17665                   Drama, Musical & Performing Arts
# 17666              Action & Adventure, Animation, Comedy
# 17667  Action & Adventure, Art House & International,...
# 17668                                    Classics, Drama
# 17669  Action & Adventure, Art House & International,...
#
#        original_release_date             production_company  \
# 0                       2010               20th Century Fox
# 1                       2010         Sony Pictures Classics
# 2                       1979                    Waner Bros.
# 3                       1957           Criterion Collection
# 4                       1954                         Disney
# ...                      ...                            ...
# 17665                   1981       MCA Universal Home Video
# 17666                   2016  Walt Disney Animation Studios
# 17667                   1964                            Fox
# 17668                   1964             Paramount Pictures
# 17669                   1979            Tango Entertainment
#
#       tomatometer_status  tomatometer_rating audience_status  audience_rating  \
# 0                 Rotten                49.0         Spilled             53.0
# 1        Certified-Fresh                87.0         Upright             64.0
# 2                  Fresh                67.0         Spilled             53.0
# 3        Certified-Fresh               100.0         Upright             97.0
# 4                  Fresh                89.0         Upright             74.0
# ...                  ...                 ...             ...              ...
# 17665             Rotten                56.0         Upright             74.0
# 17666    Certified-Fresh                98.0         Upright             92.0
# 17667              Fresh                80.0         Upright             86.0
# 17668              Fresh                96.0         Upright             91.0
# 17669             Rotten                50.0         Upright             62.0
#
#                                              review_type  \
# 0      [Fresh, Rotten, Fresh, Fresh, Fresh, Fresh, Ro...
# 1      [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Rot...
# 2      [Fresh, Fresh, Fresh, Rotten, Rotten, Rotten, ...
# 3      [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# 4      [Fresh, Fresh, Fresh, Fresh, Rotten, Fresh, Fr...
# ...                                                  ...
# 17665              [Rotten, Fresh, Fresh, Fresh, Rotten]
# 17666  [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# 17667  [Fresh, Fresh, Rotten, Fresh, Fresh, Fresh, Fr...
# 17668  [Fresh, Fresh, Fresh, Fresh, Fresh, Fresh, Fre...
# 17669  [Rotten, Fresh, Fresh, Rotten, Fresh, Fresh, R...
#
#                                             review_score  \
# 0      [3.5/5, 1/4, 3.5/5, B, 3/5, 4/5, 2/4, 2/5, 3/5...
# 1      [3/4, 3/5, 4/5, B+, 3/4, B+, 1/4, 5/5, 3/5, 4/...
# 2      [4/5, 3/5, 3/5, 2/5, 2/5, 1/5, 4/5, 2/5, 1/5, ...
# 3      [4/4, 9/10, 92/100, 4/5, A-, 5/5, 5/5, 5/5, 5/...
# 4      [7/10, 4.5/5, 4/5, 4/5, 3/5, 7/10, 5/5, 5/5, 3...
# ...                                                  ...
# 17665                           [1/5, 3/5, B-, 3/5, 2/5]
# 17666  [4/5, 6/10, 4/5, 4/5, 9/10, 8.5/10, 3.5/5, 5/5...
# 17667                [4/5, 4/5, C+, B, 4/5, 3/4, 79/100]
# 17668  [4/5, 5/5, A, 4/5, 4/5, 4/5, 4/5, 2.5/4, 3/5, ...
# 17669          [2/5, 3/5, 4/5, 2/5, 3.5/5, B+, 3.5/5, C]
#
#                                           review_content review_label
# 0      [Whether audiences will get behind The Lightni...       Rotten
# 1      [Holofcener always gives us more to chew on th...        Fresh
# 2      [Obvious but entertaining portrayal of midlife...        Fresh
# 3      [In a time of bloated when special effects hav...        Fresh
# 4      [The embodiment of Disney at his best -- famil...        Fresh
# ...                                                  ...          ...
# 17665  [, , , A curious film with a hint of authentic...        Fresh
# 17666  [The be-true-to-yourself and don't-judge-other...        Fresh
# 17667  [, , Gained international acclaim for Anthony ...        Fresh
# 17668  [, This amazing film is devastatingly accurate...        Fresh
# 17669  [, , , , Seen today, it's not only a startling...       Rotten
#
# [17670 rows x 15 columns]

# %%
tomatoes_data["review_content"].iloc[2]
# Out:
# ['Obvious but entertaining portrayal of midlife crisis gone horribly awry.',
#  '',
#  '',
#  'Highly over-rated Dudley Moore comedy.',
#  '',
#  "And oh, the irony, that the film only deserves a '1.'",
#  '',
#  'It was a big hit. I have never understood why.',
#  'Sexist, juvenile, and pathetically structured, despite the gamest efforts of its actors and the blithe willingness of its famous non-actor.',
#  'People tend to forget what a hilarious movie this really is',
#  '',
#  "Blake Edwards's 10 is perhaps the first comedy about terminal yearning. Like all great comedies, it deals with emotions very close to our hearts.",
#  '',
#  '',
#  '',
#  "This passable but not great Blake Edwards picture became known for the huge impact that the beautiful Bo Derek had on hairstyle; Bo's stardom was shortlived, though.",
#  '',
#  'Dudley Moore is periodically funny, Julie Andrews is mostly charming, and Bo Derek is always gorgeous.',
#  "10's tossed-off quality keeps it from greatness, but it also distinguishes it from the great mass of contemporary comedies smoothed to a shiny, edgeless formula. Blu-ray",
#  'A fascinating character study, bittersweet and insightful yet full of tremendous laughs.',
#  'It has some gags - some are even quite funny - but not nearly enough.']

# %%
tomatoes_data.isnull().sum()
# Out:
# rotten_tomatoes_link        0
# movie_title                 0
# critics_consensus        8539
# content_rating              0
# genres                     19
# original_release_date    1150
# production_company        492
# tomatometer_status         42
# tomatometer_rating         42
# audience_status           436
# audience_rating           284
# review_type                 0
# review_score                0
# review_content              0
# review_label                0
# dtype: int64

# %% [markdown]
# We need to make sure to only add the critics_consensus that are not `Null`

# %%
tomatoes_data["review_content"] = tomatoes_data.apply(
    lambda row: row["review_content"] + [row["critics_consensus"]] 
    if pd.notna(row["critics_consensus"]) else row["review_content"], axis=1
)

# %%
tomatoes_data = tomatoes_data.drop(columns="critics_consensus")

# %%
tomatoes_data.isnull().sum()
# Out:
# rotten_tomatoes_link        0
# movie_title                 0
# content_rating              0
# genres                     19
# original_release_date    1150
# production_company        492
# tomatometer_status         42
# tomatometer_rating         42
# audience_status           436
# audience_rating           284
# review_type                 0
# review_score                0
# review_content              0
# review_label                0
# dtype: int64

# %% [markdown]
# There are sadly a lot of missing values for the release date, but maybe we can even try to get the dates from the letterbox dataset.\\\
# I think the date is kinda important when it comes to putting the movies together in case there are movies with the same name but different years.
#
# Maybe when merging this with the letterbox data we will be able to find more years in common

# %% [markdown]
# I decided to keep the `tomatometer_status`, `tomatometer_rating`, `audience_status` and `audience_rating` since they can be also indicators on whether the movie is relevant or not for the future predictions.
#
# We already have this in the `review_label` obtained from the `review_type` column but the `tomatometer_status` provides an additional label: "Certified-Fresh". Which may not be extremely important since we are doing a binary classification so we will change it for just "Fresh"

# %%
tomatoes_data["tomatometer_status"] = tomatoes_data["tomatometer_status"].replace("Certified-Fresh", "Fresh")
tomatoes_data["tomatometer_status"]
# Out:
# 0        Rotten
# 1         Fresh
# 2         Fresh
# 3         Fresh
# 4         Fresh
#           ...
# 17665    Rotten
# 17666     Fresh
# 17667     Fresh
# 17668     Fresh
# 17669    Rotten
# Name: tomatometer_status, Length: 17670, dtype: object

# %% [markdown]
# Now the thing is that the audience rating does not usually match the tomatometer rating, sometimes a Rotten movie will be classified as Upright and a Fresh movie will be classified as Spilled. Since this project is based on using the reviews and the data from the apps it might be better to just use the data from the tomatometer. In case the predictions don't have such high accuracy we can blame it on this. I will drop them for now, if in the future we want to retrain our model with just the audience ratings they will still be there

# %%
tomatoes_data = tomatoes_data.drop(columns=["audience_status", "audience_rating"])

# %%
tomatoes_data.columns
# Out:
# Index(['rotten_tomatoes_link', 'movie_title', 'content_rating', 'genres',
#        'original_release_date', 'production_company', 'tomatometer_status',
#        'tomatometer_rating', 'review_type', 'review_score', 'review_content',
#        'review_label'],
#       dtype='object')

# %%
tomatoes_data.to_csv("movie_reviews/clean_tomatoes_data.csv", index=False)

# %% [markdown]
# ## Visualizations

# %%
# plt.style.use("ggplot")

# # Distribution of tomatometer ratings
# plt.figure(figsize=(8, 5))
# sns.histplot(tomatoes_data['tomatometer_rating'].value_counts(), bins=10, kde=True, color='dodgerblue', edgecolor='black', alpha=0.7)
# plt.xlabel('Tomatometer Rating', fontsize=12, fontweight='bold')
# plt.ylabel('Count', fontsize=12, fontweight='bold')
# plt.title('Distribution of Tomatometer Ratings', fontsize=14, fontweight='bold')
# plt.show()

tomatometer_counts = tomatoes_data['tomatometer_rating'].value_counts()

plt.style.use("ggplot")

plt.figure(figsize=(10, 6))
sns.barplot(x=tomatometer_counts.index, y=tomatometer_counts.values, hue=tomatometer_counts.index, palette="viridis", legend=False)
plt.xlabel("Tomatometer Rating", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.title("Distribution of Tomatometer Ratings", fontsize=14, fontweight='bold')
plt.xticks(ticks=range(10, 101, 10))
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
tomatoes_data['content_rating'].value_counts()
# Out:
# content_rating
# R        6371
# NR       5442
# PG-13    2977
# PG       2167
# G         675
# NC17       38
# Name: count, dtype: int64

# %%
# movies by content rating
content_rating_count = tomatoes_data['content_rating'].value_counts()

plt.figure(figsize=(8, 5))
sns.countplot(x=tomatoes_data['content_rating'], hue=tomatoes_data['content_rating'], palette='coolwarm', alpha=0.8, legend=False)
plt.xlabel('Content Rating', fontsize=12, fontweight='bold')
plt.ylabel('Number of Movies', fontsize=12, fontweight='bold')
plt.title('Count of Movies by Content Rating', fontsize=14, fontweight='bold')
plt.show()

# %%
# Create a figure with two circular pie charts
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot 1: Tomatometer Status Pie Chart
tomatoes_data['tomatometer_status'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', startangle=140, colors=sns.color_palette("pastel"), 
    ax=axes[0], wedgeprops={'edgecolor': 'black'})
axes[0].set_ylabel('')  # Remove y-axis label
axes[0].set_title('Tomatometer Status Distribution', fontsize=14, fontweight='bold')

# Plot 2: Review Type Pie Chart
tomatoes_data['review_label'].value_counts().plot(
    kind='pie', autopct='%1.1f%%', startangle=140, colors=sns.color_palette("muted"), 
    ax=axes[1], wedgeprops={'edgecolor': 'black'})
axes[1].set_ylabel('')  # Remove y-axis label
axes[1].set_title('Review Label Distribution', fontsize=14, fontweight='bold')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Join Letterbox and Rotten Tomatoes data

# %%
df_tomatoes = pd.read_csv("movie_reviews/clean_tomatoes_data.csv")
df_letterbox = pd.read_csv("movie_reviews/clean_letterbox_data.csv")

# %%
df_tomatoes.columns
# Out:
# Index(['rotten_tomatoes_link', 'movie_title', 'content_rating', 'genres',
#        'original_release_date', 'production_company', 'tomatometer_status',
#        'tomatometer_rating', 'review_type', 'review_score', 'review_content',
#        'review_label'],
#       dtype='object')

# %%
movies_not_in_tomatoes = df_letterbox[~df_letterbox["movie_name"].isin(df_tomatoes["movie_title"])]

df_tomatoes_extended = pd.concat([df_tomatoes, movies_not_in_tomatoes], ignore_index=True)
df_tomatoes_extended
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 19090                                    NaN
# 19091                                    NaN
# 19092                                    NaN
# 19093                                    NaN
# 19094                                    NaN
#
#                                              movie_title content_rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                            Please Give              R
# 2                                                     10              R
# 3                        12 Angry Men (Twelve Angry Men)             NR
# 4                           20,000 Leagues Under The Sea              G
# ...                                                  ...            ...
# 19090                                                NaN            NaN
# 19091                                                NaN            NaN
# 19092                                                NaN            NaN
# 19093                                                NaN            NaN
# 19094                                                NaN            NaN
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#        original_release_date      production_company tomatometer_status  \
# 0                     2010.0        20th Century Fox             Rotten
# 1                     2010.0  Sony Pictures Classics              Fresh
# 2                     1979.0             Waner Bros.              Fresh
# 3                     1957.0    Criterion Collection              Fresh
# 4                     1954.0                  Disney              Fresh
# ...                      ...                     ...                ...
# 19090                    NaN                     NaN                NaN
# 19091                    NaN                     NaN                NaN
# 19092                    NaN                     NaN                NaN
# 19093                    NaN                     NaN                NaN
# 19094                    NaN                     NaN                NaN
#
#        tomatometer_rating                                        review_type  \
# 0                    49.0  ['Fresh', 'Rotten', 'Fresh', 'Fresh', 'Fresh',...
# 1                    87.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 2                    67.0  ['Fresh', 'Fresh', 'Fresh', 'Rotten', 'Rotten'...
# 3                   100.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 4                    89.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Rotten',...
# ...                   ...                                                ...
# 19090                 NaN                                                NaN
# 19091                 NaN                                                NaN
# 19092                 NaN                                                NaN
# 19093                 NaN                                                NaN
# 19094                 NaN                                                NaN
#
#                                             review_score  \
# 0      ['3.5/5', '1/4', '3.5/5', 'B', '3/5', '4/5', '...
# 1      ['3/4', '3/5', '4/5', 'B+', '3/4', 'B+', '1/4'...
# 2      ['4/5', '3/5', '3/5', '2/5', '2/5', '1/5', '4/...
# 3      ['4/4', '9/10', '92/100', '4/5', 'A-', '5/5', ...
# 4      ['7/10', '4.5/5', '4/5', '4/5', '3/5', '7/10',...
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#                                           review_content review_label  \
# 0      ["Whether audiences will get behind The Lightn...       Rotten
# 1      ['Holofcener always gives us more to chew on t...        Fresh
# 2      ['Obvious but entertaining portrayal of midlif...        Fresh
# 3      ['In a time of bloated when special effects ha...        Fresh
# 4      ['The embodiment of Disney at his best -- fami...        Fresh
# ...                                                  ...          ...
# 19090                                                NaN          NaN
# 19091                                                NaN          NaN
# 19092                                                NaN          NaN
# 19093                                                NaN          NaN
# 19094                                                NaN          NaN
#
#                           movie_name  Release Year  \
# 0                                NaN           NaN
# 1                                NaN           NaN
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# ...                              ...           ...
# 19090                         Titane        2021.0
# 19091  Harry Potter 20th Anniversary        2022.0
# 19092                      Love Hard        2021.0
# 19093                 A Serbian Film        2010.0
# 19094                           CODA        2021.0
#
#                                             Clean_Review  Like count  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 19090                 the most fucked up wholesome movie      2169.0
# 19091  Laughed out loud when they said multi-million ...      2159.0
# 19092  so.....it's called Love Hard because of Love A...      2162.0
# 19093    OH MY GOD, LOOK AT HOW CONTROVERSIAL I AM!!!!!!         NaN
# 19094  Crazy how such a cliche and predictable movie ...         NaN
#
#              genre
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 19090        Drama
# 19091  Documentary
# 19092       Comedy
# 19093       Horror
# 19094        Drama
#
# [19095 rows x 17 columns]

# %%
def merge_reviews_with_comma(row):
    """Merge Rotten Tomatoes' review_content with Letterboxd's Clean_Review, separating them by commas."""
    reviews = []
    if pd.notna(row["review_content"]):
        reviews.append(row["review_content"])
    if pd.notna(row["Clean_Review"]):
        reviews.append(row["Clean_Review"])
    return ", ".join(reviews) if reviews else None

# Apply function to merge reviews with commas
df_tomatoes_extended["review_content"] = df_tomatoes_extended.apply(merge_reviews_with_comma, axis=1)
df_tomatoes_extended
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 19090                                    NaN
# 19091                                    NaN
# 19092                                    NaN
# 19093                                    NaN
# 19094                                    NaN
#
#                                              movie_title content_rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                            Please Give              R
# 2                                                     10              R
# 3                        12 Angry Men (Twelve Angry Men)             NR
# 4                           20,000 Leagues Under The Sea              G
# ...                                                  ...            ...
# 19090                                                NaN            NaN
# 19091                                                NaN            NaN
# 19092                                                NaN            NaN
# 19093                                                NaN            NaN
# 19094                                                NaN            NaN
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#        original_release_date      production_company tomatometer_status  \
# 0                     2010.0        20th Century Fox             Rotten
# 1                     2010.0  Sony Pictures Classics              Fresh
# 2                     1979.0             Waner Bros.              Fresh
# 3                     1957.0    Criterion Collection              Fresh
# 4                     1954.0                  Disney              Fresh
# ...                      ...                     ...                ...
# 19090                    NaN                     NaN                NaN
# 19091                    NaN                     NaN                NaN
# 19092                    NaN                     NaN                NaN
# 19093                    NaN                     NaN                NaN
# 19094                    NaN                     NaN                NaN
#
#        tomatometer_rating                                        review_type  \
# 0                    49.0  ['Fresh', 'Rotten', 'Fresh', 'Fresh', 'Fresh',...
# 1                    87.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 2                    67.0  ['Fresh', 'Fresh', 'Fresh', 'Rotten', 'Rotten'...
# 3                   100.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 4                    89.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Rotten',...
# ...                   ...                                                ...
# 19090                 NaN                                                NaN
# 19091                 NaN                                                NaN
# 19092                 NaN                                                NaN
# 19093                 NaN                                                NaN
# 19094                 NaN                                                NaN
#
#                                             review_score  \
# 0      ['3.5/5', '1/4', '3.5/5', 'B', '3/5', '4/5', '...
# 1      ['3/4', '3/5', '4/5', 'B+', '3/4', 'B+', '1/4'...
# 2      ['4/5', '3/5', '3/5', '2/5', '2/5', '1/5', '4/...
# 3      ['4/4', '9/10', '92/100', '4/5', 'A-', '5/5', ...
# 4      ['7/10', '4.5/5', '4/5', '4/5', '3/5', '7/10',...
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#                                           review_content review_label  \
# 0      ["Whether audiences will get behind The Lightn...       Rotten
# 1      ['Holofcener always gives us more to chew on t...        Fresh
# 2      ['Obvious but entertaining portrayal of midlif...        Fresh
# 3      ['In a time of bloated when special effects ha...        Fresh
# 4      ['The embodiment of Disney at his best -- fami...        Fresh
# ...                                                  ...          ...
# 19090                 the most fucked up wholesome movie          NaN
# 19091  Laughed out loud when they said multi-million ...          NaN
# 19092  so.....it's called Love Hard because of Love A...          NaN
# 19093    OH MY GOD, LOOK AT HOW CONTROVERSIAL I AM!!!!!!          NaN
# 19094  Crazy how such a cliche and predictable movie ...          NaN
#
#                           movie_name  Release Year  \
# 0                                NaN           NaN
# 1                                NaN           NaN
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# ...                              ...           ...
# 19090                         Titane        2021.0
# 19091  Harry Potter 20th Anniversary        2022.0
# 19092                      Love Hard        2021.0
# 19093                 A Serbian Film        2010.0
# 19094                           CODA        2021.0
#
#                                             Clean_Review  Like count  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 19090                 the most fucked up wholesome movie      2169.0
# 19091  Laughed out loud when they said multi-million ...      2159.0
# 19092  so.....it's called Love Hard because of Love A...      2162.0
# 19093    OH MY GOD, LOOK AT HOW CONTROVERSIAL I AM!!!!!!         NaN
# 19094  Crazy how such a cliche and predictable movie ...         NaN
#
#              genre
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 19090        Drama
# 19091  Documentary
# 19092       Comedy
# 19093       Horror
# 19094        Drama
#
# [19095 rows x 17 columns]

# %%
df_tomatoes_extended["movie_title"] = df_tomatoes_extended["movie_title"].combine_first(df_tomatoes_extended["movie_name"])
df_tomatoes_extended["genre"] = df_tomatoes_extended["genre"].combine_first(df_tomatoes_extended["genres"])
df_tomatoes_extended["Release Year"] = df_tomatoes_extended["Release Year"].combine_first(df_tomatoes_extended["original_release_date"])

# %%
df_tomatoes_extended
# Out:
#                         rotten_tomatoes_link  \
# 0                                  m/0814255
# 1                                  m/0878835
# 2                                       m/10
# 3                     m/1000013-12_angry_men
# 4      m/1000079-20000_leagues_under_the_sea
# ...                                      ...
# 19090                                    NaN
# 19091                                    NaN
# 19092                                    NaN
# 19093                                    NaN
# 19094                                    NaN
#
#                                              movie_title content_rating  \
# 0      Percy Jackson & the Olympians: The Lightning T...             PG
# 1                                            Please Give              R
# 2                                                     10              R
# 3                        12 Angry Men (Twelve Angry Men)             NR
# 4                           20,000 Leagues Under The Sea              G
# ...                                                  ...            ...
# 19090                                             Titane            NaN
# 19091                      Harry Potter 20th Anniversary            NaN
# 19092                                          Love Hard            NaN
# 19093                                     A Serbian Film            NaN
# 19094                                               CODA            NaN
#
#                                                   genres  \
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#        original_release_date      production_company tomatometer_status  \
# 0                     2010.0        20th Century Fox             Rotten
# 1                     2010.0  Sony Pictures Classics              Fresh
# 2                     1979.0             Waner Bros.              Fresh
# 3                     1957.0    Criterion Collection              Fresh
# 4                     1954.0                  Disney              Fresh
# ...                      ...                     ...                ...
# 19090                    NaN                     NaN                NaN
# 19091                    NaN                     NaN                NaN
# 19092                    NaN                     NaN                NaN
# 19093                    NaN                     NaN                NaN
# 19094                    NaN                     NaN                NaN
#
#        tomatometer_rating                                        review_type  \
# 0                    49.0  ['Fresh', 'Rotten', 'Fresh', 'Fresh', 'Fresh',...
# 1                    87.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 2                    67.0  ['Fresh', 'Fresh', 'Fresh', 'Rotten', 'Rotten'...
# 3                   100.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 4                    89.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Rotten',...
# ...                   ...                                                ...
# 19090                 NaN                                                NaN
# 19091                 NaN                                                NaN
# 19092                 NaN                                                NaN
# 19093                 NaN                                                NaN
# 19094                 NaN                                                NaN
#
#                                             review_score  \
# 0      ['3.5/5', '1/4', '3.5/5', 'B', '3/5', '4/5', '...
# 1      ['3/4', '3/5', '4/5', 'B+', '3/4', 'B+', '1/4'...
# 2      ['4/5', '3/5', '3/5', '2/5', '2/5', '1/5', '4/...
# 3      ['4/4', '9/10', '92/100', '4/5', 'A-', '5/5', ...
# 4      ['7/10', '4.5/5', '4/5', '4/5', '3/5', '7/10',...
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#                                           review_content review_label  \
# 0      ["Whether audiences will get behind The Lightn...       Rotten
# 1      ['Holofcener always gives us more to chew on t...        Fresh
# 2      ['Obvious but entertaining portrayal of midlif...        Fresh
# 3      ['In a time of bloated when special effects ha...        Fresh
# 4      ['The embodiment of Disney at his best -- fami...        Fresh
# ...                                                  ...          ...
# 19090                 the most fucked up wholesome movie          NaN
# 19091  Laughed out loud when they said multi-million ...          NaN
# 19092  so.....it's called Love Hard because of Love A...          NaN
# 19093    OH MY GOD, LOOK AT HOW CONTROVERSIAL I AM!!!!!!          NaN
# 19094  Crazy how such a cliche and predictable movie ...          NaN
#
#                           movie_name  Release Year  \
# 0                                NaN        2010.0
# 1                                NaN        2010.0
# 2                                NaN        1979.0
# 3                                NaN        1957.0
# 4                                NaN        1954.0
# ...                              ...           ...
# 19090                         Titane        2021.0
# 19091  Harry Potter 20th Anniversary        2022.0
# 19092                      Love Hard        2021.0
# 19093                 A Serbian Film        2010.0
# 19094                           CODA        2021.0
#
#                                             Clean_Review  Like count  \
# 0                                                    NaN         NaN
# 1                                                    NaN         NaN
# 2                                                    NaN         NaN
# 3                                                    NaN         NaN
# 4                                                    NaN         NaN
# ...                                                  ...         ...
# 19090                 the most fucked up wholesome movie      2169.0
# 19091  Laughed out loud when they said multi-million ...      2159.0
# 19092  so.....it's called Love Hard because of Love A...      2162.0
# 19093    OH MY GOD, LOOK AT HOW CONTROVERSIAL I AM!!!!!!         NaN
# 19094  Crazy how such a cliche and predictable movie ...         NaN
#
#                                                    genre
# 0      Action & Adventure, Comedy, Drama, Science Fic...
# 1                                                 Comedy
# 2                                        Comedy, Romance
# 3                                        Classics, Drama
# 4               Action & Adventure, Drama, Kids & Family
# ...                                                  ...
# 19090                                              Drama
# 19091                                        Documentary
# 19092                                             Comedy
# 19093                                             Horror
# 19094                                              Drama
#
# [19095 rows x 17 columns]

# %%
df_tomatoes_extended.drop(columns=["rotten_tomatoes_link", "movie_name", "genres", "original_release_date", "Clean_Review", "Like count", "content_rating", "production_company"], inplace=True, errors="ignore")
df_tomatoes_extended
# Out:
#                                              movie_title tomatometer_status  \
# 0      Percy Jackson & the Olympians: The Lightning T...             Rotten
# 1                                            Please Give              Fresh
# 2                                                     10              Fresh
# 3                        12 Angry Men (Twelve Angry Men)              Fresh
# 4                           20,000 Leagues Under The Sea              Fresh
# ...                                                  ...                ...
# 19090                                             Titane                NaN
# 19091                      Harry Potter 20th Anniversary                NaN
# 19092                                          Love Hard                NaN
# 19093                                     A Serbian Film                NaN
# 19094                                               CODA                NaN
#
#        tomatometer_rating                                        review_type  \
# 0                    49.0  ['Fresh', 'Rotten', 'Fresh', 'Fresh', 'Fresh',...
# 1                    87.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 2                    67.0  ['Fresh', 'Fresh', 'Fresh', 'Rotten', 'Rotten'...
# 3                   100.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Fresh', ...
# 4                    89.0  ['Fresh', 'Fresh', 'Fresh', 'Fresh', 'Rotten',...
# ...                   ...                                                ...
# 19090                 NaN                                                NaN
# 19091                 NaN                                                NaN
# 19092                 NaN                                                NaN
# 19093                 NaN                                                NaN
# 19094                 NaN                                                NaN
#
#                                             review_score  \
# 0      ['3.5/5', '1/4', '3.5/5', 'B', '3/5', '4/5', '...
# 1      ['3/4', '3/5', '4/5', 'B+', '3/4', 'B+', '1/4'...
# 2      ['4/5', '3/5', '3/5', '2/5', '2/5', '1/5', '4/...
# 3      ['4/4', '9/10', '92/100', '4/5', 'A-', '5/5', ...
# 4      ['7/10', '4.5/5', '4/5', '4/5', '3/5', '7/10',...
# ...                                                  ...
# 19090                                                NaN
# 19091                                                NaN
# 19092                                                NaN
# 19093                                                NaN
# 19094                                                NaN
#
#                                           review_content review_label  \
# 0      ["Whether audiences will get behind The Lightn...       Rotten
# 1      ['Holofcener always gives us more to chew on t...        Fresh
# 2      ['Obvious but entertaining portrayal of midlif...        Fresh
# 3      ['In a time of bloated when special effects ha...        Fresh
# 4      ['The embodiment of Disney at his best -- fami...        Fresh
# ...                                                  ...          ...
# 19090                 the most fucked up wholesome movie          NaN
# 19091  Laughed out loud when they said multi-million ...          NaN
# 19092  so.....it's called Love Hard because of Love A...          NaN
# 19093    OH MY GOD, LOOK AT HOW CONTROVERSIAL I AM!!!!!!          NaN
# 19094  Crazy how such a cliche and predictable movie ...          NaN
#
#        Release Year                                              genre
# 0            2010.0  Action & Adventure, Comedy, Drama, Science Fic...
# 1            2010.0                                             Comedy
# 2            1979.0                                    Comedy, Romance
# 3            1957.0                                    Classics, Drama
# 4            1954.0           Action & Adventure, Drama, Kids & Family
# ...             ...                                                ...
# 19090        2021.0                                              Drama
# 19091        2022.0                                        Documentary
# 19092        2021.0                                             Comedy
# 19093        2010.0                                             Horror
# 19094        2021.0                                              Drama
#
# [19095 rows x 9 columns]

# %%
df_tomatoes_extended.to_csv("movie_reviews/final_movie_reviews.csv", index=False)
